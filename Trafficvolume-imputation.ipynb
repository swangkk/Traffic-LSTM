# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
traffin = pd.read_excel('F:\\교통량 2008-2018\\2008년 도로 종류별 교통량.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f89e36e36f37> in <module>
# ----> 1 traffin = pd.read_excel('F:\\교통량 2008-2018\\2008년 도로 종류별 교통량.xlsx')
#
# ~\Anaconda3\envs\Keras\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ~\Anaconda3\envs\Keras\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     308
#     309     if not isinstance(io, ExcelFile):
# ...
