# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import LSTM, Dense, Activation, BatchNormalization
from keras.callbacks import TensorBoard

from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
df_data = pd.read_csv('traffic.csv')
print(df_data.shape)
# Out:
# (8760, 4)

# %%
df_data.head(10)
# Out:
#          Date  Weekday  Time  Traffic
# 0  2014-01-01        4     0      581
# 1  2014-01-01        4     1      532
# 2  2014-01-01        4     2      465
# 3  2014-01-01        4     3      432
# 4  2014-01-01        4     4      297
# 5  2014-01-01        4     5      283
# 6  2014-01-01        4     6      264
# 7  2014-01-01        4     7      350
# 8  2014-01-01        4     8      458
# 9  2014-01-01        4     9      706

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 4 columns):
# Date       8760 non-null object
# Weekday    8760 non-null int64
# Time       8760 non-null int64
# Traffic    8760 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 273.9+ KB

# %%
#   df_data['Time'] = pd.to_datetime(df_data['Time'])

# %%
''' 
hour, minute, second = [], [], []
for i in range(np.size(df_data, 0)):
    hour.append(df_data['Time'][i].hour)
    minute.append(df_data['Time'][i].minute)
    second.append(df_data['Time'][i].second)
    '''
# Out:
# " \nhour, minute, second = [], [], []\nfor i in range(np.size(df_data, 0)):\n    hour.append(df_data['Time'][i].hour)\n    minute.append(df_data['Time'][i].minute)\n    second.append(df_data['Time'][i].second)\n    "

# %%
'''
hour = np.array(hour).reshape(-1, 1)
minute = np.array(minute).reshape(-1, 1)
second = np.array(second).reshape(-1, 1)

print(hour.shape, minute.shape, second.shape)
'''
# Out:
# '\nhour = np.array(hour).reshape(-1, 1)\nminute = np.array(minute).reshape(-1, 1)\nsecond = np.array(second).reshape(-1, 1)\n\nprint(hour.shape, minute.shape, second.shape)\n'

# %%
traffic = df_data['Traffic'].values.reshape(-1, 1)
print(traffic.shape)
# Out:
# (8760, 1)

# %%
time = df_data['Time'].values.reshape(-1, 1)
print(time.shape)
# Out:
# (8760, 1)

# %%
weekday = df_data['Weekday'].values.reshape(-1, 1)
print(weekday.shape)
# Out:
# (8760, 1)

# %%
data = np.concatenate((weekday, time, traffic), axis=1)
print(data.shape)
# Out:
# (8760, 3)

# %%
data[:10]
# Out:
# array([[  4,   0, 581],
#        [  4,   1, 532],
#        [  4,   2, 465],
#        [  4,   3, 432],
#        [  4,   4, 297],
#        [  4,   5, 283],
#        [  4,   6, 264],
#        [  4,   7, 350],
#        [  4,   8, 458],
#        [  4,   9, 706]], dtype=int64)

# %%
train_data = data[:7000]
train_traffic = traffic[:7000]
print(train_data.shape, train_traffic.shape)
# Out:
# (7000, 3) (7000, 1)

# %%
test_data = data[7001:]
test_traffic = traffic[7001:]
print(test_data.shape, test_traffic.shape)
# Out:
# (1759, 3) (1759, 1)

# %%
lag=24 # 몇개 데이터 후를 예측 ?

# %%
arr = []
for i in range(24):
    arr.append(train_data[i:i-lag,:])

arr = np.array(arr, dtype=np.float32)
print(arr.shape)
# Out:
# (24, 6976, 3)

# %%
#arr[:15,:10,:4]

# %%
x_train_val = np.concatenate((arr[0], arr[1], arr[2], arr[3], arr[4]), axis=1).reshape(-1, 5, 3)
#, arr[5], arr[6], arr[7], arr[8], arr[9], arr[10], arr[11], arr[12], arr[13], arr[14], arr[15], arr[16], arr[17], arr[18], arr[19], arr[20], arr[21], arr[22], arr[23]
train_mean, train_std = np.mean(x_train_val, axis=0), np.std(x_train_val, axis=0)
train_mean, train_std = np.mean(train_mean, axis=0), np.mean(train_std, axis=0)

# %%
y_train_val = train_traffic[lag:, :].reshape(-1, 1)

# %%
print(x_train_val.shape, y_train_val.shape)
# Out:
# (6976, 5, 3) (6976, 1)

# %%
arr = []
for i in range(24):
    arr.append(test_data[i:i-lag,:])
    
arr = np.array(arr, dtype=np.float32)
print(arr.shape)
# Out:
# (24, 1735, 3)

# %%
x_test = np.concatenate((arr[0], arr[1], arr[2], arr[3], arr[4]), axis=1).reshape(-1, 5, 3)
y_test = test_traffic[lag:, :].reshape(-1, 1)
print(x_test.shape, y_test.shape)
# Out:
# (1735, 5, 3) (1735, 1)

# %%
# split into training and validation datasets
x_train, x_val, y_train, y_val = train_test_split(x_train_val, y_train_val, test_size=0.2)
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (5580, 5, 3) (5580, 1) (1396, 5, 3) (1396, 1)

# %%
h_units = 64
activation_ = 'relu'

def rnn_model():
    model = Sequential()
    
    model.add(LSTM(units=h_units, return_sequences=True, input_shape=(5, 3))) #마지막 LSTM은 FALSE로 끝나야함
    model.add(LSTM(units=h_units, return_sequences=False)) #마지막 LSTM은 FALSE로 끝나야함
    model.add(Dense(64))
    model.add(Dense(1))
    
    return model

# %%
# create a model 
model = rnn_model()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_17 (LSTM)               (None, 5, 64)             17408
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dense_21 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 54,657
# Trainable params: 54,657
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# training
tensorBoard = TensorBoard(log_dir='./logs', histogram_freq=0, write_graph=True, write_images=False)

hist = model.fit(x_train, y_train, epochs=120, batch_size=512, verbose=True, validation_data=(x_val, y_val), shuffle=True, callbacks=[tensorBoard])
# Out:
# Train on 5580 samples, validate on 1396 samples
# Epoch 1/120
# 5580/5580 [==============================] - 1s 252us/step - loss: 2296789.6789 - val_loss: 2300035.1877
# Epoch 2/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 2284789.1805 - val_loss: 2282323.9334
# Epoch 3/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 2260946.1900 - val_loss: 2249826.3166
# Epoch 4/120
# 5580/5580 [==============================] - 0s 42us/step - loss: 2223385.6789 - val_loss: 2210073.9484
# Epoch 5/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 2183543.0855 - val_loss: 2169216.3904
# Epoch 6/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 2141628.3754 - val_loss: 2125857.1977
# Epoch 7/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 2096097.3959 - val_loss: 2078228.4112
# Epoch 8/120
# 5580/5580 [==============================] - 0s 42us/step - loss: 2046150.9751 - val_loss: 2026018.5953
# Epoch 9/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 1991575.8408 - val_loss: 1968756.5906
# Epoch 10/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 1932327.9694 - val_loss: 1907666.9269
# Epoch 11/120
# 5580/5580 [==============================] - 0s 39us/step - loss: 1869476.3001 - val_loss: 1843452.9319
# Epoch 12/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 1803796.6010 - val_loss: 1776265.3689
# Epoch 13/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 1735320.6060 - val_loss: 1706930.8403
# Epoch 14/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 1664907.7789 - val_loss: 1635914.6870
# Epoch 15/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 1593291.9650 - val_loss: 1563724.9710
# Epoch 16/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 1520775.4853 - val_loss: 1491211.5150
# Epoch 17/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 1447980.4823 - val_loss: 1419111.4337
# Epoch 18/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 1375883.6123 - val_loss: 1347854.8349
# Epoch 19/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 1304920.6833 - val_loss: 1278090.3997
# Epoch 20/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 1235901.6806 - val_loss: 1210178.0860
# Epoch 21/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 1168524.0767 - val_loss: 1145258.5380
# Epoch 22/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 1104857.4703 - val_loss: 1082919.5716
# Epoch 23/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 1044105.3067 - val_loss: 1023971.2324
# Epoch 24/120
# 5580/5580 [==============================] - 0s 39us/step - loss: 986278.5562 - val_loss: 969442.1257
# Epoch 25/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 933146.5488 - val_loss: 918737.4384
# Epoch 26/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 883661.2208 - val_loss: 872425.6777
# Epoch 27/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 839246.9659 - val_loss: 829871.3832
# Epoch 28/120
# 5580/5580 [==============================] - 0s 39us/step - loss: 798459.1681 - val_loss: 791864.7984
# Epoch 29/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 762166.7919 - val_loss: 758186.9407
# Epoch 30/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 730081.5794 - val_loss: 728668.6271
# Epoch 31/120
# 5580/5580 [==============================] - 0s 39us/step - loss: 702170.6615 - val_loss: 702962.7210
# Epoch 32/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 677745.7926 - val_loss: 680711.0677
# Epoch 33/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 613772.2878 - val_loss: 549239.4302
# Epoch 34/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 521189.2333 - val_loss: 496915.9131
# Epoch 35/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 485444.5943 - val_loss: 444832.5162
# Epoch 36/120
# 5580/5580 [==============================] - 0s 42us/step - loss: 431284.2207 - val_loss: 434282.1570
# Epoch 37/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 391094.9816 - val_loss: 366771.7821
# Epoch 38/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 345167.0767 - val_loss: 339784.4350
# Epoch 39/120
# 5580/5580 [==============================] - 0s 39us/step - loss: 308176.7797 - val_loss: 290928.2770
# Epoch 40/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 274326.7013 - val_loss: 260783.1187
# Epoch 41/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 247134.6363 - val_loss: 235413.4768
# Epoch 42/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 221989.4509 - val_loss: 212960.6306
# Epoch 43/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 200470.1508 - val_loss: 193023.7521
# Epoch 44/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 183600.4144 - val_loss: 175546.7456
# Epoch 45/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 171227.2166 - val_loss: 162088.7610
# Epoch 46/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 155204.5554 - val_loss: 152531.0171
# Epoch 47/120
# 5580/5580 [==============================] - 0s 42us/step - loss: 141231.9813 - val_loss: 135926.2492
# Epoch 48/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 130415.3183 - val_loss: 124015.4313
# Epoch 49/120
# 5580/5580 [==============================] - 0s 43us/step - loss: 123298.9726 - val_loss: 120762.1832
# Epoch 50/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 143054.9690 - val_loss: 223956.6920
# Epoch 51/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 187189.5403 - val_loss: 149818.6166
# Epoch 52/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 148858.7430 - val_loss: 144657.5607
# Epoch 53/120
# 5580/5580 [==============================] - 0s 39us/step - loss: 124351.6142 - val_loss: 103794.6195
# Epoch 54/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 111331.3980 - val_loss: 110073.6530
# Epoch 55/120
# 5580/5580 [==============================] - 0s 39us/step - loss: 105752.7611 - val_loss: 109524.8112
# Epoch 56/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 93723.9446 - val_loss: 85305.4069
# Epoch 57/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 85701.7515 - val_loss: 82681.3930
# Epoch 58/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 82265.8115 - val_loss: 75307.0612
# Epoch 59/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 78488.4469 - val_loss: 72677.8383
# Epoch 60/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 74579.8466 - val_loss: 71461.0608
# Epoch 61/120
# 5580/5580 [==============================] - 0s 39us/step - loss: 71250.8818 - val_loss: 65576.0434
# Epoch 62/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 70431.3018 - val_loss: 67059.5173
# Epoch 63/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 68339.3577 - val_loss: 62394.8075
# Epoch 64/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 66806.0117 - val_loss: 64946.1234
# Epoch 65/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 65190.1519 - val_loss: 59007.1340
# Epoch 66/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 60887.8044 - val_loss: 56307.7157
# Epoch 67/120
# 5580/5580 [==============================] - 0s 39us/step - loss: 58948.0040 - val_loss: 57129.6119
# Epoch 68/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 58228.0687 - val_loss: 52826.2191
# Epoch 69/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 58515.5946 - val_loss: 77252.1607
# Epoch 70/120
# 5580/5580 [==============================] - 0s 39us/step - loss: 60069.4286 - val_loss: 62827.3161
# Epoch 71/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 58077.5587 - val_loss: 51145.3584
# Epoch 72/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 56230.0194 - val_loss: 49635.3883
# Epoch 73/120
# 5580/5580 [==============================] - 0s 39us/step - loss: 52553.3958 - val_loss: 47463.3009
# Epoch 74/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 52529.7121 - val_loss: 50200.9711
# Epoch 75/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 50246.4777 - val_loss: 46018.4886
# Epoch 76/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 52821.3058 - val_loss: 54525.3427
# Epoch 77/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 51583.0549 - val_loss: 45004.7537
# Epoch 78/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 49723.8888 - val_loss: 45166.2681
# Epoch 79/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 47366.1340 - val_loss: 43709.8314
# Epoch 80/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 46659.5354 - val_loss: 43304.8810
# Epoch 81/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 46456.9781 - val_loss: 42385.0118
# Epoch 82/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 48361.2512 - val_loss: 48947.8042
# Epoch 83/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 48053.6757 - val_loss: 41895.0170
# Epoch 84/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 45143.0135 - val_loss: 40800.9610
# Epoch 85/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 44064.3054 - val_loss: 42624.7491
# Epoch 86/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 44604.6591 - val_loss: 44274.6505
# Epoch 87/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 43130.3388 - val_loss: 40452.9483
# Epoch 88/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 43290.8459 - val_loss: 39813.3751
# Epoch 89/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 43365.5122 - val_loss: 41209.9145
# Epoch 90/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 42830.8842 - val_loss: 41233.2950
# Epoch 91/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 42866.3032 - val_loss: 43033.6494
# Epoch 92/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 42137.5641 - val_loss: 36504.0733
# Epoch 93/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 39975.5808 - val_loss: 37530.4372
# Epoch 94/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 43610.8732 - val_loss: 36384.3893
# Epoch 95/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 38029.5018 - val_loss: 39586.3812
# Epoch 96/120
# 5580/5580 [==============================] - 0s 39us/step - loss: 43363.8130 - val_loss: 47663.2305
# Epoch 97/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 53465.7509 - val_loss: 43739.2280
# Epoch 98/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 43143.0717 - val_loss: 40810.8656
# Epoch 99/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 39428.7658 - val_loss: 36936.6208
# Epoch 100/120
# 5580/5580 [==============================] - 0s 39us/step - loss: 40859.2178 - val_loss: 64986.7924
# Epoch 101/120
# 5580/5580 [==============================] - 0s 39us/step - loss: 60944.3935 - val_loss: 44139.1207
# Epoch 102/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 46836.1840 - val_loss: 41434.1663
# Epoch 103/120
# 5580/5580 [==============================] - 0s 39us/step - loss: 48439.6676 - val_loss: 53413.6738
# Epoch 104/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 45390.3500 - val_loss: 38467.9603
# Epoch 105/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 38537.7266 - val_loss: 36454.6673
# Epoch 106/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 38034.5832 - val_loss: 33419.6845
# Epoch 107/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 37576.1012 - val_loss: 33029.2624
# Epoch 108/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 38156.7982 - val_loss: 32540.2899
# Epoch 109/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 33762.5005 - val_loss: 31687.0372
# Epoch 110/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 35002.8296 - val_loss: 36271.4215
# Epoch 111/120
# 5580/5580 [==============================] - 0s 43us/step - loss: 35694.1166 - val_loss: 31302.4346
# Epoch 112/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 33108.1590 - val_loss: 37309.8820
# Epoch 113/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 35847.9991 - val_loss: 33772.5662
# Epoch 114/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 33962.1805 - val_loss: 33252.5677
# Epoch 115/120
# 5580/5580 [==============================] - 0s 41us/step - loss: 34948.5427 - val_loss: 31752.2756
# Epoch 116/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 35112.9872 - val_loss: 30165.5203
# Epoch 117/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 48007.9555 - val_loss: 75630.0083
# Epoch 118/120
# 5580/5580 [==============================] - 0s 39us/step - loss: 52240.1346 - val_loss: 40401.2405
# Epoch 119/120
# 5580/5580 [==============================] - 0s 35us/step - loss: 41121.5088 - val_loss: 36979.0441
# Epoch 120/120
# 5580/5580 [==============================] - 0s 40us/step - loss: 38365.5209 - val_loss: 34455.1751

# %%
y_pred = model.predict(x_test, batch_size=512, verbose=True) 
print(y_pred.shape)
print(model.evaluate(x_test, y_test,batch_size=512))
# Out:
# 1735/1735 [==============================] - 1s 303us/step
# (1735, 1)
# 1735/1735 [==============================] - 0s 20us/step
# 41582.13192768372

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()

loss_ax.plot(hist.history['loss'], 'b', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='test loss')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')

loss_ax.legend(loc='upper right')

plt.show()

# %%
# visualization for prediction result
# set figure size
plt.figure(figsize=(19,8))

# set font
font = {'family': 'Arial', 'weight': 'normal', 'size': 16}
plt.rc('font', **font)

# plot data 
plt.plot(y_test[:,0], 'r', label='y_true')
plt.plot(y_pred[:,0], 'b', label='y_pred')

# set legend position
plt.legend(shadow=True, loc='upper right')

# set x-axis & y-axis titles
#plt.title('prediction result')
plt.xlabel('Time Index')
plt.ylabel('Brightness')

# set axis-limits
plt.xlim(left = 0, right = len(y_test)) 
plt.ylim(bottom = 0.3) 

# set grid
plt.grid(color='gray', linestyle='--', linewidth=1)

plt.xticks(np.arange(0,1500,500))
plt.yticks(np.arange(0,2800,400))

# save & display figure
plt.show()

# %%
#모델 평가하기
trainScore = model.evaluate(x_train, y_train, verbose=0)
print('Train Score: ', trainScore)
#valScore = model.evaluate(x_val, y_val, verbose=0)
#print('Validataion Score: ', valScore)
testScore = model.evaluate(x_test, y_test, verbose=0)
print('Test Score: ', testScore)
# Out:
# Train Score:  36143.35346032146
# Test Score:  41582.132452269456

# %%
#MAPE

y_test, y_pred = np.array(y_test), np.array(y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print('MAPE: ', mape)
# Out:
# MAPE:  15.205195488736202
